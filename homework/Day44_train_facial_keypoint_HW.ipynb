# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = r'D:\Roger\AI_team\1st-DL-CVMarathon_handout\day042\training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 印出網路結構
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 6s 4ms/step - loss: 0.0071 - val_loss: 0.0021
#
# Epoch 00001: val_loss improved from inf to 0.00214, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00214 to 0.00193, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 1s 833us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00193 to 0.00185, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00004: val_loss did not improve from 0.00185
# Epoch 5/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00185
# Epoch 6/150
# 1712/1712 [==============================] - 1s 834us/step - loss: 0.0010 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00185
# Epoch 7/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 9.8287e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00185 to 0.00175, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 8.8908e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00175 to 0.00162, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 7.4090e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00162 to 0.00144, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 6.5135e-04 - val_loss: 0.0013
#
# Epoch 00010: val_loss improved from 0.00144 to 0.00133, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 5.7516e-04 - val_loss: 0.0012
#
# Epoch 00011: val_loss improved from 0.00133 to 0.00121, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 5.2125e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00121 to 0.00111, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 4.8465e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00111 to 0.00108, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 4.4739e-04 - val_loss: 9.7320e-04
#
# Epoch 00014: val_loss improved from 0.00108 to 0.00097, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 4.1862e-04 - val_loss: 9.4441e-04
#
# Epoch 00015: val_loss improved from 0.00097 to 0.00094, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 3.9150e-04 - val_loss: 9.3730e-04
#
# Epoch 00016: val_loss improved from 0.00094 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 3.6716e-04 - val_loss: 8.6031e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00086, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 3.5098e-04 - val_loss: 8.3219e-04
#
# Epoch 00018: val_loss improved from 0.00086 to 0.00083, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 3.4188e-04 - val_loss: 8.3372e-04
#
# Epoch 00019: val_loss did not improve from 0.00083
# Epoch 20/150
# 1712/1712 [==============================] - 1s 833us/step - loss: 3.2701e-04 - val_loss: 8.2482e-04
#
# Epoch 00020: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 1s 834us/step - loss: 3.1581e-04 - val_loss: 8.1661e-04
#
# Epoch 00021: val_loss improved from 0.00082 to 0.00082, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 1s 836us/step - loss: 3.0121e-04 - val_loss: 8.7335e-04
#
# Epoch 00022: val_loss did not improve from 0.00082
# Epoch 23/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 2.9614e-04 - val_loss: 8.0073e-04
#
# Epoch 00023: val_loss improved from 0.00082 to 0.00080, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 1s 835us/step - loss: 2.8909e-04 - val_loss: 7.9519e-04
#
# Epoch 00024: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 1s 833us/step - loss: 2.9085e-04 - val_loss: 8.4175e-04
#
# Epoch 00025: val_loss did not improve from 0.00080
# Epoch 26/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 2.8225e-04 - val_loss: 7.7802e-04
#
# Epoch 00026: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 1s 829us/step - loss: 2.6593e-04 - val_loss: 8.3261e-04
#
# Epoch 00027: val_loss did not improve from 0.00078
# Epoch 28/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 2.6238e-04 - val_loss: 8.6289e-04
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 2.5688e-04 - val_loss: 7.8827e-04
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 2.4868e-04 - val_loss: 7.6322e-04
#
# Epoch 00030: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 2.5036e-04 - val_loss: 7.6981e-04
#
# Epoch 00031: val_loss did not improve from 0.00076
# Epoch 32/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 2.4207e-04 - val_loss: 7.6162e-04
#
# Epoch 00032: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 2.3811e-04 - val_loss: 7.4216e-04
#
# Epoch 00033: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 2.3766e-04 - val_loss: 7.6205e-04
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 1712/1712 [==============================] - 1s 829us/step - loss: 2.2009e-04 - val_loss: 7.5462e-04
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 2.1978e-04 - val_loss: 7.0963e-04
#
# Epoch 00036: val_loss improved from 0.00074 to 0.00071, saving model to best_weights.h5
# Epoch 37/150
# 1712/1712 [==============================] - 1s 833us/step - loss: 2.2241e-04 - val_loss: 7.9071e-04
#
# Epoch 00037: val_loss did not improve from 0.00071
# Epoch 38/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 2.2452e-04 - val_loss: 7.4234e-04
#
# Epoch 00038: val_loss did not improve from 0.00071
# Epoch 39/150
# 1712/1712 [==============================] - 1s 829us/step - loss: 2.1735e-04 - val_loss: 7.0892e-04
#
# Epoch 00039: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 40/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 2.0563e-04 - val_loss: 7.3514e-04
#
# Epoch 00040: val_loss did not improve from 0.00071
# Epoch 41/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 2.0257e-04 - val_loss: 7.4522e-04
#
# Epoch 00041: val_loss did not improve from 0.00071
# Epoch 42/150
# 1712/1712 [==============================] - 1s 834us/step - loss: 1.9943e-04 - val_loss: 7.4580e-04
#
# Epoch 00042: val_loss did not improve from 0.00071
# Epoch 43/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 2.0056e-04 - val_loss: 7.4683e-04
#
# Epoch 00043: val_loss did not improve from 0.00071
# Epoch 44/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.9283e-04 - val_loss: 7.8553e-04
#
# Epoch 00044: val_loss did not improve from 0.00071
# Epoch 45/150
# 1712/1712 [==============================] - 1s 833us/step - loss: 1.9229e-04 - val_loss: 7.9763e-04
#
# Epoch 00045: val_loss did not improve from 0.00071
# Epoch 46/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.8901e-04 - val_loss: 7.0835e-04
#
# Epoch 00046: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 1.8618e-04 - val_loss: 7.3438e-04
#
# Epoch 00047: val_loss did not improve from 0.00071
# Epoch 48/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.8614e-04 - val_loss: 7.1798e-04
#
# Epoch 00048: val_loss did not improve from 0.00071
# Epoch 49/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 1.8949e-04 - val_loss: 7.3246e-04
#
# Epoch 00049: val_loss did not improve from 0.00071
# Epoch 50/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.7920e-04 - val_loss: 7.2015e-04
#
# Epoch 00050: val_loss did not improve from 0.00071
# Epoch 51/150
# 1712/1712 [==============================] - 1s 821us/step - loss: 1.7943e-04 - val_loss: 7.3636e-04
#
# Epoch 00051: val_loss did not improve from 0.00071
# Epoch 52/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.7962e-04 - val_loss: 7.5689e-04
#
# Epoch 00052: val_loss did not improve from 0.00071
# Epoch 53/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.7181e-04 - val_loss: 6.7987e-04
#
# Epoch 00053: val_loss improved from 0.00071 to 0.00068, saving model to best_weights.h5
# Epoch 54/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.7164e-04 - val_loss: 7.5857e-04
#
# Epoch 00054: val_loss did not improve from 0.00068
# Epoch 55/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.7368e-04 - val_loss: 7.3043e-04
#
# Epoch 00055: val_loss did not improve from 0.00068
# Epoch 56/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.6333e-04 - val_loss: 7.0796e-04
#
# Epoch 00056: val_loss did not improve from 0.00068
# Epoch 57/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.6275e-04 - val_loss: 7.1703e-04
#
# Epoch 00057: val_loss did not improve from 0.00068
# Epoch 58/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.6111e-04 - val_loss: 7.3054e-04
#
# Epoch 00058: val_loss did not improve from 0.00068
# Epoch 59/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.6221e-04 - val_loss: 7.2272e-04
#
# Epoch 00059: val_loss did not improve from 0.00068
# Epoch 60/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.5536e-04 - val_loss: 7.1159e-04
#
# Epoch 00060: val_loss did not improve from 0.00068
# Epoch 61/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.6086e-04 - val_loss: 6.9828e-04
#
# Epoch 00061: val_loss did not improve from 0.00068
# Epoch 62/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 1.5410e-04 - val_loss: 6.9275e-04
#
# Epoch 00062: val_loss did not improve from 0.00068
# Epoch 63/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 1.5746e-04 - val_loss: 7.5437e-04
#
# Epoch 00063: val_loss did not improve from 0.00068
# Epoch 64/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.5972e-04 - val_loss: 6.7713e-04
#
# Epoch 00064: val_loss improved from 0.00068 to 0.00068, saving model to best_weights.h5
# Epoch 65/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 1.5808e-04 - val_loss: 7.0916e-04
#
# Epoch 00065: val_loss did not improve from 0.00068
# Epoch 66/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.5264e-04 - val_loss: 7.2597e-04
#
# Epoch 00066: val_loss did not improve from 0.00068
# Epoch 67/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.4596e-04 - val_loss: 7.2999e-04
#
# Epoch 00067: val_loss did not improve from 0.00068
# Epoch 68/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.4870e-04 - val_loss: 6.9370e-04
#
# Epoch 00068: val_loss did not improve from 0.00068
# Epoch 69/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.4839e-04 - val_loss: 6.9597e-04
#
# Epoch 00069: val_loss did not improve from 0.00068
# Epoch 70/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 1.4548e-04 - val_loss: 6.9469e-04
#
# Epoch 00070: val_loss did not improve from 0.00068
# Epoch 71/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.3975e-04 - val_loss: 7.0762e-04
#
# Epoch 00071: val_loss did not improve from 0.00068
# Epoch 72/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.4147e-04 - val_loss: 7.8153e-04
#
# Epoch 00072: val_loss did not improve from 0.00068
# Epoch 73/150
# 1712/1712 [==============================] - 1s 821us/step - loss: 1.3936e-04 - val_loss: 6.9504e-04
#
# Epoch 00073: val_loss did not improve from 0.00068
# Epoch 74/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.3660e-04 - val_loss: 7.1604e-04
#
# Epoch 00074: val_loss did not improve from 0.00068
# Epoch 75/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.3660e-04 - val_loss: 7.5259e-04
#
# Epoch 00075: val_loss did not improve from 0.00068
# Epoch 76/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.3148e-04 - val_loss: 7.2640e-04
#
# Epoch 00076: val_loss did not improve from 0.00068
# Epoch 77/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.3040e-04 - val_loss: 6.9386e-04
#
# Epoch 00077: val_loss did not improve from 0.00068
# Epoch 78/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.3523e-04 - val_loss: 7.2112e-04
#
# Epoch 00078: val_loss did not improve from 0.00068
# Epoch 79/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.3380e-04 - val_loss: 6.9946e-04
#
# Epoch 00079: val_loss did not improve from 0.00068
# Epoch 80/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 1.2736e-04 - val_loss: 7.1922e-04
#
# Epoch 00080: val_loss did not improve from 0.00068
# Epoch 81/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.3055e-04 - val_loss: 7.0807e-04
#
# Epoch 00081: val_loss did not improve from 0.00068
# Epoch 82/150
# 1712/1712 [==============================] - 1s 820us/step - loss: 1.3194e-04 - val_loss: 6.9230e-04
#
# Epoch 00082: val_loss did not improve from 0.00068
# Epoch 83/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.2818e-04 - val_loss: 7.0397e-04
#
# Epoch 00083: val_loss did not improve from 0.00068
# Epoch 84/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 1.2958e-04 - val_loss: 7.2547e-04
#
# Epoch 00084: val_loss did not improve from 0.00068
# Epoch 85/150
# 1712/1712 [==============================] - 1s 836us/step - loss: 1.2372e-04 - val_loss: 6.9919e-04
#
# Epoch 00085: val_loss did not improve from 0.00068
# Epoch 86/150
# 1712/1712 [==============================] - 1s 844us/step - loss: 1.2974e-04 - val_loss: 7.3990e-04
#
# Epoch 00086: val_loss did not improve from 0.00068
# Epoch 87/150
# 1712/1712 [==============================] - 1s 835us/step - loss: 1.2484e-04 - val_loss: 7.5110e-04
#
# Epoch 00087: val_loss did not improve from 0.00068
# Epoch 88/150
# 1712/1712 [==============================] - 1s 841us/step - loss: 1.2488e-04 - val_loss: 7.0518e-04
#
# Epoch 00088: val_loss did not improve from 0.00068
# Epoch 89/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 1.1575e-04 - val_loss: 7.0696e-04
#
# Epoch 00089: val_loss did not improve from 0.00068
# Epoch 90/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 1.1861e-04 - val_loss: 7.1426e-04
#
# Epoch 00090: val_loss did not improve from 0.00068
# Epoch 91/150
# 1712/1712 [==============================] - 1s 849us/step - loss: 1.1916e-04 - val_loss: 7.0355e-04
#
# Epoch 00091: val_loss did not improve from 0.00068
# Epoch 92/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.1764e-04 - val_loss: 7.1840e-04
#
# Epoch 00092: val_loss did not improve from 0.00068
# Epoch 93/150
# 1712/1712 [==============================] - 1s 835us/step - loss: 1.1854e-04 - val_loss: 7.1031e-04
#
# Epoch 00093: val_loss did not improve from 0.00068
# Epoch 94/150
# 1712/1712 [==============================] - 1s 820us/step - loss: 1.1561e-04 - val_loss: 7.3111e-04
#
# Epoch 00094: val_loss did not improve from 0.00068
# Epoch 95/150
# 1712/1712 [==============================] - 1s 821us/step - loss: 1.1503e-04 - val_loss: 7.1070e-04
#
# Epoch 00095: val_loss did not improve from 0.00068
# Epoch 96/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 1.1581e-04 - val_loss: 7.1024e-04
#
# Epoch 00096: val_loss did not improve from 0.00068
# Epoch 97/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.1472e-04 - val_loss: 6.8902e-04
#
# Epoch 00097: val_loss did not improve from 0.00068
# Epoch 98/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 1.0952e-04 - val_loss: 7.5402e-04
#
# Epoch 00098: val_loss did not improve from 0.00068
# Epoch 99/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.1663e-04 - val_loss: 7.4203e-04
#
# Epoch 00099: val_loss did not improve from 0.00068
# Epoch 100/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 1.1363e-04 - val_loss: 7.5132e-04
#
# Epoch 00100: val_loss did not improve from 0.00068
# Epoch 101/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 1.1063e-04 - val_loss: 7.0725e-04
#
# Epoch 00101: val_loss did not improve from 0.00068
# Epoch 102/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.1092e-04 - val_loss: 7.1656e-04
#
# Epoch 00102: val_loss did not improve from 0.00068
# Epoch 103/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.1276e-04 - val_loss: 7.2386e-04
#
# Epoch 00103: val_loss did not improve from 0.00068
# Epoch 104/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 1.0926e-04 - val_loss: 7.2943e-04
#
# Epoch 00104: val_loss did not improve from 0.00068
# Epoch 105/150
# 1712/1712 [==============================] - 1s 823us/step - loss: 1.0965e-04 - val_loss: 6.9777e-04
#
# Epoch 00105: val_loss did not improve from 0.00068
# Epoch 106/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 1.0906e-04 - val_loss: 6.9362e-04
#
# Epoch 00106: val_loss did not improve from 0.00068
# Epoch 107/150
# 1712/1712 [==============================] - 1s 871us/step - loss: 1.0923e-04 - val_loss: 7.4954e-04
#
# Epoch 00107: val_loss did not improve from 0.00068
# Epoch 108/150
# 1712/1712 [==============================] - 1s 847us/step - loss: 1.0663e-04 - val_loss: 7.1459e-04
#
# Epoch 00108: val_loss did not improve from 0.00068
# Epoch 109/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 1.0642e-04 - val_loss: 7.5424e-04
#
# Epoch 00109: val_loss did not improve from 0.00068
# Epoch 110/150
# 1712/1712 [==============================] - 1s 839us/step - loss: 1.0224e-04 - val_loss: 7.3913e-04
#
# Epoch 00110: val_loss did not improve from 0.00068
# Epoch 111/150
# 1712/1712 [==============================] - 1s 842us/step - loss: 1.0377e-04 - val_loss: 7.0680e-04
#
# Epoch 00111: val_loss did not improve from 0.00068
# Epoch 112/150
# 1712/1712 [==============================] - 1s 832us/step - loss: 1.0435e-04 - val_loss: 7.2402e-04
#
# Epoch 00112: val_loss did not improve from 0.00068
# Epoch 113/150
# 1712/1712 [==============================] - 1s 836us/step - loss: 1.0067e-04 - val_loss: 7.4757e-04
#
# Epoch 00113: val_loss did not improve from 0.00068
# Epoch 114/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 1.0139e-04 - val_loss: 7.4767e-04
#
# Epoch 00114: val_loss did not improve from 0.00068
# Epoch 115/150
# 1712/1712 [==============================] - 1s 835us/step - loss: 9.9915e-05 - val_loss: 7.2257e-04
#
# Epoch 00115: val_loss did not improve from 0.00068
# Epoch 116/150
# 1712/1712 [==============================] - 1s 847us/step - loss: 1.0022e-04 - val_loss: 7.2605e-04
#
# Epoch 00116: val_loss did not improve from 0.00068
# Epoch 117/150
# 1712/1712 [==============================] - 1s 842us/step - loss: 9.8155e-05 - val_loss: 7.1891e-04
#
# Epoch 00117: val_loss did not improve from 0.00068
# Epoch 118/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 9.7129e-05 - val_loss: 7.5721e-04
#
# Epoch 00118: val_loss did not improve from 0.00068
# Epoch 119/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 9.8052e-05 - val_loss: 7.3839e-04
#
# Epoch 00119: val_loss did not improve from 0.00068
# Epoch 120/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 9.5603e-05 - val_loss: 6.9672e-04
#
# Epoch 00120: val_loss did not improve from 0.00068
# Epoch 121/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 9.4564e-05 - val_loss: 7.1740e-04
#
# Epoch 00121: val_loss did not improve from 0.00068
# Epoch 122/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 9.4648e-05 - val_loss: 7.1215e-04
#
# Epoch 00122: val_loss did not improve from 0.00068
# Epoch 123/150
# 1712/1712 [==============================] - 1s 829us/step - loss: 9.2813e-05 - val_loss: 7.4742e-04
#
# Epoch 00123: val_loss did not improve from 0.00068
# Epoch 124/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 9.4467e-05 - val_loss: 7.0482e-04
#
# Epoch 00124: val_loss did not improve from 0.00068
# Epoch 125/150
# 1712/1712 [==============================] - 1s 847us/step - loss: 9.3652e-05 - val_loss: 7.5407e-04
#
# Epoch 00125: val_loss did not improve from 0.00068
# Epoch 126/150
# 1712/1712 [==============================] - 1s 842us/step - loss: 9.3735e-05 - val_loss: 7.6884e-04
#
# Epoch 00126: val_loss did not improve from 0.00068
# Epoch 127/150
# 1712/1712 [==============================] - 1s 826us/step - loss: 9.2426e-05 - val_loss: 7.3893e-04
#
# Epoch 00127: val_loss did not improve from 0.00068
# Epoch 128/150
# 1712/1712 [==============================] - 1s 845us/step - loss: 9.3556e-05 - val_loss: 7.4276e-04
#
# Epoch 00128: val_loss did not improve from 0.00068
# Epoch 129/150
# 1712/1712 [==============================] - 1s 834us/step - loss: 8.9026e-05 - val_loss: 7.3386e-04
#
# Epoch 00129: val_loss did not improve from 0.00068
# Epoch 130/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 8.8809e-05 - val_loss: 7.0515e-04
#
# Epoch 00130: val_loss did not improve from 0.00068
# Epoch 131/150
# 1712/1712 [==============================] - 1s 819us/step - loss: 9.0576e-05 - val_loss: 7.1638e-04
#
# Epoch 00131: val_loss did not improve from 0.00068
# Epoch 132/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 8.9976e-05 - val_loss: 7.4021e-04
#
# Epoch 00132: val_loss did not improve from 0.00068
# Epoch 133/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 8.9826e-05 - val_loss: 7.2240e-04
#
# Epoch 00133: val_loss did not improve from 0.00068
# Epoch 134/150
# 1712/1712 [==============================] - 1s 820us/step - loss: 9.0122e-05 - val_loss: 6.9671e-04
#
# Epoch 00134: val_loss did not improve from 0.00068
# Epoch 135/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 8.9226e-05 - val_loss: 6.9752e-04
#
# Epoch 00135: val_loss did not improve from 0.00068
# Epoch 136/150
# 1712/1712 [==============================] - 1s 837us/step - loss: 8.8476e-05 - val_loss: 7.2839e-04
#
# Epoch 00136: val_loss did not improve from 0.00068
# Epoch 137/150
# 1712/1712 [==============================] - 1s 828us/step - loss: 8.8562e-05 - val_loss: 7.3409e-04
#
# Epoch 00137: val_loss did not improve from 0.00068
# Epoch 138/150
# 1712/1712 [==============================] - 1s 825us/step - loss: 8.7261e-05 - val_loss: 7.2002e-04
#
# Epoch 00138: val_loss did not improve from 0.00068
# Epoch 139/150
# 1712/1712 [==============================] - 1s 824us/step - loss: 8.9819e-05 - val_loss: 7.6765e-04
#
# Epoch 00139: val_loss did not improve from 0.00068
# Epoch 140/150
# 1712/1712 [==============================] - 1s 838us/step - loss: 8.9533e-05 - val_loss: 7.3799e-04
#
# Epoch 00140: val_loss did not improve from 0.00068
# Epoch 141/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 8.7274e-05 - val_loss: 7.3481e-04
#
# Epoch 00141: val_loss did not improve from 0.00068
# Epoch 142/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 8.4793e-05 - val_loss: 7.2961e-04
#
# Epoch 00142: val_loss did not improve from 0.00068
# Epoch 143/150
# 1712/1712 [==============================] - 1s 822us/step - loss: 8.3780e-05 - val_loss: 7.3762e-04
#
# Epoch 00143: val_loss did not improve from 0.00068
# Epoch 144/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 8.4567e-05 - val_loss: 7.2519e-04
#
# Epoch 00144: val_loss did not improve from 0.00068
# Epoch 145/150
# 1712/1712 [==============================] - 1s 827us/step - loss: 8.4559e-05 - val_loss: 7.1998e-04
#
# Epoch 00145: val_loss did not improve from 0.00068
# Epoch 146/150
# 1712/1712 [==============================] - 1s 839us/step - loss: 8.3757e-05 - val_loss: 7.7383e-04
#
# Epoch 00146: val_loss did not improve from 0.00068
# Epoch 147/150
# 1712/1712 [==============================] - 1s 830us/step - loss: 8.4077e-05 - val_loss: 7.1041e-04
#
# Epoch 00147: val_loss did not improve from 0.00068
# Epoch 148/150
# 1712/1712 [==============================] - 1s 842us/step - loss: 8.6030e-05 - val_loss: 7.2715e-04
#
# Epoch 00148: val_loss did not improve from 0.00068
# Epoch 149/150
# 1712/1712 [==============================] - 1s 835us/step - loss: 8.5066e-05 - val_loss: 7.3386e-04
#
# Epoch 00149: val_loss did not improve from 0.00068
# Epoch 150/150
# 1712/1712 [==============================] - 1s 831us/step - loss: 8.4412e-05 - val_loss: 7.0661e-04
#
# Epoch 00150: val_loss did not improve from 0.00068

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = r'D:\Roger\AI_team\1st-DL-CVMarathon_handout\day042\test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)

hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, 
                                                  nb_epoch = 20, callbacks=[checkpoint, hist],
                                                  shuffle=True, validation_data=(train_X, points_train))
# Out:
# C:\Users\06006647\AppData\Local\conda\conda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """
# C:\Users\06006647\AppData\Local\conda\conda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., steps_per_epoch=66, shuffle=True, callbacks=[<keras.ca..., validation_data=(array([[[..., epochs=20)`
#   """
# Epoch 1/20
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0047 - val_loss: 0.0011
#
# Epoch 00001: val_loss did not improve from 0.00068
# Epoch 2/20
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0015 - val_loss: 0.0013
#
# Epoch 00002: val_loss did not improve from 0.00068
# Epoch 3/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00068
# Epoch 4/20
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00068
# Epoch 5/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00068
# Epoch 6/20
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00068
# Epoch 7/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00068
# Epoch 8/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00068
# Epoch 9/20
# 66/66 [==============================] - 3s 42ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00068
# Epoch 10/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00068
# Epoch 11/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00068
# Epoch 12/20
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00068
# Epoch 13/20
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00068
# Epoch 14/20
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00068
# Epoch 15/20
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00068
# Epoch 16/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00068
# Epoch 17/20
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00068
# Epoch 18/20
# 66/66 [==============================] - 3s 41ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00068
# Epoch 19/20
# 66/66 [==============================] - 3s 39ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00068
# Epoch 20/20
# 66/66 [==============================] - 3s 40ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00068

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
# Out:
# C:\Users\06006647\AppData\Local\conda\conda\envs\tf-gpu\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
